# %% [markdown]
# ## Exercise 1
#
# ---

# %%
print(type(data["sport"][0]))
# Out:
# <class 'numpy.int64'>

# %%
# replace the new value in the column

for i in range(len(data)):
  data["sport"][i] = round(data["sport"][i]/60, 2)
print(data)
# Out:
#      sex   city   age   bmi  bmi_score  pet  sport  time
# 0      f      3  25.4  34.1       34.1    0  44.60  2023
# 1      f      1  19.9  22.4       22.4    1  50.10  2023
# 2      f  city2  21.3  17.0       17.0    1  38.38  2023
# 3    NaN      1  23.0  17.6       17.6    0  51.22  2023
# 4      f      1  15.0  17.6       17.6    1  64.30  2023
# ..   ...    ...   ...   ...        ...  ...    ...   ...
# 287    f      3  16.1  20.8       20.8    1  54.67  2023
# 288    f      1  30.6  29.8       29.8    0   0.23  2023
# 289  NaN      2  33.1  24.5       24.5    0  19.80  2023
# 290    m  city2  29.0  24.2       24.2    0   8.12  2023
# 291    m      1  35.6  27.6       27.6    1  31.93  2023
#
# [292 rows x 8 columns]
# <ipython-input-12-18688c151628>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["sport"][i] = round(data["sport"][i]/60, 2)

# %%
# replace the new value in the column

for i in range(len(data)):
  data["sport"][i] = round(data["sport"][i]/60, 2)
print(data)
# Out:
#      sex   city   age   bmi  bmi_score  pet  sport  time
# 0      f      3  25.4  34.1       34.1    0  44.60  2023
# 1      f      1  19.9  22.4       22.4    1  50.10  2023
# 2      f  city2  21.3  17.0       17.0    1  38.38  2023
# 3    NaN      1  23.0  17.6       17.6    0  51.22  2023
# 4      f      1  15.0  17.6       17.6    1  64.30  2023
# ..   ...    ...   ...   ...        ...  ...    ...   ...
# 287    f      3  16.1  20.8       20.8    1  54.67  2023
# 288    f      1  30.6  29.8       29.8    0   0.23  2023
# 289  NaN      2  33.1  24.5       24.5    0  19.80  2023
# 290    m  city2  29.0  24.2       24.2    0   8.12  2023
# 291    m      1  35.6  27.6       27.6    1  31.93  2023
#
# [292 rows x 8 columns]
# <ipython-input-12-18688c151628>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["sport"][i] = round(data["sport"][i]/60, 2)

# %% [markdown]
# ## Exercise 2
#
# ---

# %%
# replace the new value in the column

for i in range(len(data)):

  if data["city"][i] == "city1":
    data["city"][i] = "1"
  elif data["city"][i] == "city2":
    data["city"][i] = "2"
  else:
    continue

print(data)
# Out:
#      sex city   age   bmi  bmi_score  pet  sport  time
# 0      f    3  25.4  34.1       34.1    0  44.60  2023
# 1      f    1  19.9  22.4       22.4    1  50.10  2023
# 2      f    2  21.3  17.0       17.0    1  38.38  2023
# 3    NaN    1  23.0  17.6       17.6    0  51.22  2023
# 4      f    1  15.0  17.6       17.6    1  64.30  2023
# ..   ...  ...   ...   ...        ...  ...    ...   ...
# 287    f    3  16.1  20.8       20.8    1  54.67  2023
# 288    f    1  30.6  29.8       29.8    0   0.23  2023
# 289  NaN    2  33.1  24.5       24.5    0  19.80  2023
# 290    m    2  29.0  24.2       24.2    0   8.12  2023
# 291    m    1  35.6  27.6       27.6    1  31.93  2023
#
# [292 rows x 8 columns]
# <ipython-input-13-775564502d2e>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["city"][i] = "2"
# <ipython-input-13-775564502d2e>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["city"][i] = "1"

# %% [markdown]
# ## Exercise 3
#
# ---

# %%
# replace the new value in the column

for i in range(len(data)):
   data["age"][i] = np.round_(data["age"][i], decimals =0)
print(data)
# Out:
#      sex city   age   bmi  bmi_score  pet  sport  time
# 0      f    3  25.0  34.1       34.1    0  44.60  2023
# 1      f    1  20.0  22.4       22.4    1  50.10  2023
# 2      f    2  21.0  17.0       17.0    1  38.38  2023
# 3    NaN    1  23.0  17.6       17.6    0  51.22  2023
# 4      f    1  15.0  17.6       17.6    1  64.30  2023
# ..   ...  ...   ...   ...        ...  ...    ...   ...
# 287    f    3  16.0  20.8       20.8    1  54.67  2023
# 288    f    1  31.0  29.8       29.8    0   0.23  2023
# 289  NaN    2  33.0  24.5       24.5    0  19.80  2023
# 290    m    2  29.0  24.2       24.2    0   8.12  2023
# 291    m    1  36.0  27.6       27.6    1  31.93  2023
#
# [292 rows x 8 columns]
# <ipython-input-14-3efc825fdc2a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["age"][i] = np.round_(data["age"][i], decimals =0)

# %% [markdown]
# ## Exercise 4
#
# ---

# %%
# we should have 6 columns after removing
data.drop(data.columns[[4, 5]], axis=1, inplace=True)
print(data)
# Out:
#      sex city   age   bmi  sport  time
# 0      f    3  25.0  34.1  44.60  2023
# 1      f    1  20.0  22.4  50.10  2023
# 2      f    2  21.0  17.0  38.38  2023
# 3    NaN    1  23.0  17.6  51.22  2023
# 4      f    1  15.0  17.6  64.30  2023
# ..   ...  ...   ...   ...    ...   ...
# 287    f    3  16.0  20.8  54.67  2023
# 288    f    1  31.0  29.8   0.23  2023
# 289  NaN    2  33.0  24.5  19.80  2023
# 290    m    2  29.0  24.2   8.12  2023
# 291    m    1  36.0  27.6  31.93  2023
#
# [292 rows x 6 columns]

# %% [markdown]
# ## Exercise 5
#
# ---

# %%
data['time'].value_counts()
# Out:
# 2023    291
# 2018      1
# Name: time, dtype: int64

# %%
# Hint: check the "time" column

for i in range(len(data)):
  if data['time'][i] == 2018:
    data = data.drop([data.index[i]])
  else:
    continue

# %%
data['time'].value_counts()
# Out:
# 2023    291
# Name: time, dtype: int64

# %% [markdown]
# ## Exercise 6
#
# ---

# %%
data.sort_values("sport", axis = 0, ascending = False)
# Out:
#     sex city   age   bmi    sport  time
# 217   m    2  31.0  32.6  1202.25  2023
# 259   m    1  39.0  37.3  1074.82  2023
# 9     m    3  40.0  29.8   119.27  2023
# 134   f    3  31.0  25.1   119.27  2023
# 68    f    1  18.0  22.3   119.02  2023
# ..   ..  ...   ...   ...      ...   ...
# 218   f    1  26.0  26.6     0.98  2023
# 149   f    3  26.0  22.8     0.93  2023
# 166   m    3  30.0  23.8     0.88  2023
# 210   f    2  45.0  41.4     0.45  2023
# 288   f    1  31.0  29.8     0.23  2023
#
# [291 rows x 6 columns]

# %%
# Hint: check the "sport" column
data = data.drop([data.index[217], data.index[259]])

# %%
data.sort_values("sport", axis = 0, ascending = False)
# Out:
#     sex city   age   bmi   sport  time
# 134   f    3  31.0  25.1  119.27  2023
# 9     m    3  40.0  29.8  119.27  2023
# 68    f    1  18.0  22.3  119.02  2023
# 222   m    2  35.0  40.8  118.83  2023
# 146   m    2  27.0  29.0  118.55  2023
# ..   ..  ...   ...   ...     ...   ...
# 218   f    1  26.0  26.6    0.98  2023
# 149   f    3  26.0  22.8    0.93  2023
# 166   m    3  30.0  23.8    0.88  2023
# 210   f    2  45.0  41.4    0.45  2023
# 288   f    1  31.0  29.8    0.23  2023
#
# [289 rows x 6 columns]

# %% [markdown]
# ## Exercise 7
#
# ---

# %%
# remove the unnecessary rows
data = data[data["age"] > 18]

# %%
data.describe()
# Out:
#               age         bmi       sport    time
# count  261.000000  258.000000  261.000000   261.0
# mean    33.283525   29.622868   57.621762  2023.0
# std      8.606576    7.352708   34.179999     0.0
# min     19.000000   16.000000    0.230000  2023.0
# 25%     26.000000   24.225000   28.580000  2023.0
# 50%     33.000000   28.950000   57.780000  2023.0
# 75%     40.000000   35.975000   85.950000  2023.0
# max     56.000000   42.000000  119.270000  2023.0

# %% [markdown]
# ## Exercise 8
#
# ---

# %%
# calculate the bmi mean over all nan values first.
data["bmi"] = data["bmi"].fillna(data["bmi"].mean())
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 261 entries, 0 to 291
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sex     257 non-null    object
#  1   city    261 non-null    object
#  2   age     261 non-null    float64
#  3   bmi     261 non-null    float64
#  4   sport   261 non-null    float64
#  5   time    261 non-null    int64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 14.3+ KB

# %% [markdown]
# ## Exercise 9
#
# ---

# %%
# we should have 3 nan values in the sex column
data = data[data["sex"].notnull()]
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 257 entries, 0 to 291
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sex     257 non-null    object
#  1   city    257 non-null    object
#  2   age     257 non-null    float64
#  3   bmi     257 non-null    float64
#  4   sport   257 non-null    float64
#  5   time    257 non-null    int64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 14.1+ KB

# %%
data
# Out:
#     sex city   age   bmi  sport  time
# 0     f    3  25.0  34.1  44.60  2023
# 1     f    1  20.0  22.4  50.10  2023
# 2     f    2  21.0  17.0  38.38  2023
# 5     f    3  49.0  39.6  41.03  2023
# 6     f    3  47.0  35.2  27.13  2023
# ..   ..  ...   ...   ...    ...   ...
# 285   m    3  27.0  28.8  77.47  2023
# 286   f    2  56.0  39.4  70.40  2023
# 288   f    1  31.0  29.8   0.23  2023
# 290   m    2  29.0  24.2   8.12  2023
# 291   m    1  36.0  27.6  31.93  2023
#
# [257 rows x 6 columns]

# %% [markdown]
# ## Exercise 10
#
# ---

# %%
# store results in the new data frame with the name "selected_data"
selected_data = data[(data['city'] == "1") & (data['bmi'] > 25) & (data['sport'] <= 60)]
selected_data
# Out:
#     sex city   age        bmi  sport  time
# 11    f    1  50.0  41.900000  20.20  2023
# 15    m    1  35.0  41.500000  27.30  2023
# 17    f    1  42.0  29.622868  29.07  2023
# 20    f    1  26.0  31.800000  50.83  2023
# 28    f    1  36.0  41.200000  28.85  2023
# 32    f    1  36.0  31.400000  47.62  2023
# 36    f    1  36.0  25.100000  12.88  2023
# 38    f    1  31.0  32.600000  59.50  2023
# 48    m    1  28.0  27.200000  37.43  2023
# 49    m    1  30.0  29.600000   8.43  2023
# 102   f    1  35.0  34.300000  54.65  2023
# 104   m    1  44.0  40.900000  55.67  2023
# 106   f    1  32.0  38.500000  29.72  2023
# 108   m    1  42.0  29.900000  28.58  2023
# 125   f    1  35.0  38.300000   6.02  2023
# 137   f    1  42.0  40.100000  29.28  2023
# 145   f    1  39.0  25.500000  39.45  2023
# 148   f    1  28.0  25.500000  51.30  2023
# 151   f    1  33.0  33.700000  34.78  2023
# 153   f    1  35.0  29.600000  38.55  2023
# 163   f    1  43.0  34.700000  18.75  2023
# 168   f    1  45.0  40.200000  32.10  2023
# 169   m    1  30.0  29.500000  55.72  2023
# 172   m    1  31.0  25.700000  50.40  2023
# 190   m    1  43.0  40.000000   1.05  2023
# 206   f    1  34.0  30.800000  52.33  2023
# 218   f    1  26.0  26.600000   0.98  2023
# 219   f    1  32.0  25.800000  51.50  2023
# 224   m    1  37.0  39.300000   6.53  2023
# 225   f    1  30.0  36.000000  38.85  2023
# 229   f    1  38.0  38.700000  41.33  2023
# 233   m    1  40.0  26.500000  59.63  2023
# 236   m    1  38.0  28.700000  15.07  2023
# 243   m    1  47.0  38.300000  18.63  2023
# 263   f    1  25.0  26.700000  31.98  2023
# 280   m    1  43.0  31.600000  37.12  2023
# 281   f    1  42.0  41.000000  26.85  2023
# 284   m    1  47.0  38.700000  40.47  2023
# 288   f    1  31.0  29.800000   0.23  2023
# 291   m    1  36.0  27.600000  31.93  2023

# %%
selected_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40 entries, 11 to 291
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sex     40 non-null     object
#  1   city    40 non-null     object
#  2   age     40 non-null     float64
#  3   bmi     40 non-null     float64
#  4   sport   40 non-null     float64
#  5   time    40 non-null     int64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 2.2+ KB

# %% [markdown]
# ## Exercise 11
#
# ---

# %%
# Hint: check the "sort_values" function

sorted_data = data[(data['sex'] == "f") & (data['age'] > 18) 
                    & (data['age'] < 30)].sort_values(by=['sport'], ascending=False)
sorted_data
# Out:
#     sex city   age        bmi   sport  time
# 215   f    1  28.0  28.600000  115.97  2023
# 21    f    1  21.0  28.400000  114.52  2023
# 282   f    3  26.0  19.800000  107.32  2023
# 19    f    1  26.0  17.600000  104.80  2023
# 107   f    1  19.0  16.800000  102.95  2023
# 122   f    1  21.0  22.900000   97.07  2023
# 71    f    2  20.0  17.500000   93.85  2023
# 25    f    2  24.0  25.600000   93.03  2023
# 212   f    1  25.0  26.200000   92.20  2023
# 158   f    1  21.0  16.100000   88.50  2023
# 156   f    3  28.0  17.200000   86.38  2023
# 278   f    3  21.0  23.400000   86.00  2023
# 187   f    2  26.0  22.400000   85.95  2023
# 12    f    1  24.0  25.400000   85.70  2023
# 120   f    1  19.0  21.800000   83.02  2023
# 119   f    2  21.0  18.200000   79.77  2023
# 73    f    2  25.0  19.000000   70.90  2023
# 264   f    1  23.0  25.700000   67.90  2023
# 131   f    1  22.0  21.200000   65.58  2023
# 89    f    2  22.0  17.800000   64.63  2023
# 45    f    1  20.0  19.800000   63.57  2023
# 103   f    3  25.0  32.500000   60.38  2023
# 105   f    1  20.0  18.700000   58.85  2023
# 161   f    1  21.0  18.100000   57.78  2023
# 148   f    1  28.0  25.500000   51.30  2023
# 20    f    1  26.0  31.800000   50.83  2023
# 116   f    2  20.0  25.700000   50.22  2023
# 1     f    1  20.0  22.400000   50.10  2023
# 237   f    1  27.0  16.000000   45.70  2023
# 0     f    3  25.0  34.100000   44.60  2023
# 147   f    2  29.0  25.800000   39.03  2023
# 2     f    2  21.0  17.000000   38.38  2023
# 130   f    1  23.0  20.000000   37.87  2023
# 235   f    3  26.0  29.700000   34.25  2023
# 72    f    3  27.0  28.200000   33.43  2023
# 263   f    1  25.0  26.700000   31.98  2023
# 22    f    2  23.0  23.400000   29.57  2023
# 111   f    3  20.0  25.500000   28.12  2023
# 117   f    1  25.0  21.800000   26.67  2023
# 232   f    1  19.0  20.800000   22.88  2023
# 279   f    1  29.0  24.800000   12.63  2023
# 124   f    1  21.0  17.700000   10.07  2023
# 44    f    1  23.0  24.700000    8.22  2023
# 193   f    2  26.0  29.622868    7.38  2023
# 254   f    2  25.0  23.600000    6.73  2023
# 93    f    3  26.0  30.000000    4.18  2023
# 136   f    3  28.0  35.500000    3.37  2023
# 218   f    1  26.0  26.600000    0.98  2023
# 149   f    3  26.0  22.800000    0.93  2023

# %%
sorted_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49 entries, 215 to 149
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   sex     49 non-null     object
#  1   city    49 non-null     object
#  2   age     49 non-null     float64
#  3   bmi     49 non-null     float64
#  4   sport   49 non-null     float64
#  5   time    49 non-null     int64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 2.7+ KB

# %% [markdown]
# ## Exercise 12
#
# ---

# %%
# Hint: returns the mean of the values in "bmi", grouped by the values in "city"

data.groupby(['sex']).mean()
# Out:
# <ipython-input-69-a6de1cafa60a>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(['sex']).mean()
#            age        bmi      sport    time
# sex
# f    33.916667  29.838755  55.922179  2023.0
# m    32.613861  29.570523  61.373465  2023.0

# %% [markdown]
# ## Exercise 13
#
# ---

# %%
# Hint: check "corr()" function 
data.corr()
# Out:
# <ipython-input-68-c9c77e65e019>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#             age       bmi     sport  time
# age    1.000000  0.750839 -0.038145   NaN
# bmi    0.750839  1.000000 -0.081205   NaN
# sport -0.038145 -0.081205  1.000000   NaN
# time        NaN       NaN       NaN   NaN

# %% [markdown]
# ## Exercise 14
#
# ---

# %%
data
# Out:
#     sex city   age   bmi  sport  time
# 0     f    3  25.0  34.1  44.60  2023
# 1     f    1  20.0  22.4  50.10  2023
# 2     f    2  21.0  17.0  38.38  2023
# 5     f    3  49.0  39.6  41.03  2023
# 6     f    3  47.0  35.2  27.13  2023
# ..   ..  ...   ...   ...    ...   ...
# 285   m    3  27.0  28.8  77.47  2023
# 286   f    2  56.0  39.4  70.40  2023
# 288   f    1  31.0  29.8   0.23  2023
# 290   m    2  29.0  24.2   8.12  2023
# 291   m    1  36.0  27.6  31.93  2023
#
# [257 rows x 6 columns]

# %%
# Hint: import "SciPy" library and implement student's t-test by "scipy.stats.t"
import scipy.stats as stats

data_group1 = data[data["sex"] == "m"]["bmi"]
data_group2 = data[data["sex"] == "f"]["bmi"]

# if ratio is less than 4:1, so variance is equal
print(np.var(data_group1), np.var(data_group2))
# Out:
# 49.949829379946806 55.06095160583295

# %%
def get_ttest(x, y):
  result = stats.ttest_ind(a=x, b=y, equal_var=True)
  return result

get_ttest(data_group1,data_group2)
# Out:
# Ttest_indResult(statistic=-0.28722170336999675, pvalue=0.7741758301475985)

# %% [markdown]
# ## Exercise 15
#
# ---

# %%
# use the previous function

data_group3 = data[(data["age"] > 18) & (data["age"] < 25)]["bmi"]
data_group4 = data[(data["age"] > 45) & (data["age"] < 55)]["bmi"]
print(np.var(data_group3), np.var(data_group4))
get_ttest(data_group3,data_group4)
# Out:
# 15.173064271317148 5.897278911564623
# Ttest_indResult(statistic=-17.253079283882823, pvalue=5.900678573659376e-26)

# %% [markdown]
# ## Exercise 16
#
# ---

# %%
# Hint: implement the one-way ANOVA test by "scipy.stats.f_oneway"
from scipy.stats import f_oneway

data_group5 = data[data["city"] == "1"]["bmi"]
data_group6 = data[data["city"] == "2"]["bmi"]
data_group7 = data[data["city"] == "3"]["bmi"]

f_oneway(data_group5, data_group6, data_group7)
# Out:
# F_onewayResult(statistic=1.8823788193487985, pvalue=0.1543449952170188)

# %% [markdown]
# ## Exercise 17
#
# ---

# %%
# first import matplotlib

import matplotlib.pyplot as plt

x = data["age"]
y = data["bmi"]

plt.scatter(x, y, c ="yellow",
            linewidths = 1,
            marker ="^",
            edgecolor ="blue",
            s = 20)

plt.xlabel("AGE",fontsize=12)
plt.ylabel("BMI",fontsize=12)
plt.title("DATASET",fontsize=12)
plt.show()

# %% [markdown]
# ## Exercise 18
#
# ---

# %%
# try to follow the standards of a scientific figure (title, scale,...)

sport_avg = data.groupby(['city']).mean()

cities = ["1","2","3"]
sport = sport_avg["sport"].tolist()
  
fig = plt.figure(figsize = (5, 2.5))
 
# creating the bar plot
plt.bar(cities, sport, color ='maroon', width = 0.8)
 
plt.xlabel("CITY")
plt.ylabel("SPORT")
plt.title("average sports per city")
plt.show()
# Out:
# <ipython-input-134-b8fa6dfae124>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   sport_avg = data.groupby(['city']).mean()

# %% [markdown]
# ## Exercise 19
#
# ---

# %%
# try to make the colors and fonts legible

city1_bmi = data[data["city"]=="1"]["bmi"].to_numpy()
city2_bmi = data[data["city"]=="2"]["bmi"].to_numpy()
city3_bmi = data[data["city"]=="3"]["bmi"].to_numpy()

boxplot_data = [city1_bmi, city2_bmi, city3_bmi]

fig = plt.figure(figsize =(5, 3))

 
# Creating axes instance
ax = fig.add_axes([0, 0, 1, 1])
 
# Creating plot
bp = ax.boxplot(boxplot_data)
 
# show plot
plt.show()

# %% [markdown]
# ## Exercise 20
#
# ---

# %%
# choose a meaningful name for the file names.

# saving the dataframe
data.to_csv('cleaned_data.csv', header=True, index=True)
